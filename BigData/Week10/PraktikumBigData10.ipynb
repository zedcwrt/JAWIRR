# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.9 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 21.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
# !curl ifconfig.me
# Out:
# 35.236.216.178

# %%
from pymongo import MongoClient

# Inisialisasi client dan koneksi ke database
client = MongoClient('mongodb+srv://zedankiller:fariz098_@cluster0.q4vom.mongodb.net/')
db = client['company_db']
collection = db['employees']

# Contoh untuk memastikan koneksi
print('Connected to MongoDB')
# Out:
# Connected to MongoDB

# %%
# Contoh Insert Data
employee_data = {
    'name': 'Alice',
    'department': 'Finance',
    'age': 29,
    'salary': 4500
}
collection.insert_one(employee_data)
print('Data inserted')
# Out:
# Data inserted

# %%
# Query Aggregation untuk mencari rata-rata gaji per departemen
pipeline = [
    {'$group': {'_id': '$department', 'average_salary': {'$avg': '$salary'}}}
]
for result in collection.aggregate(pipeline):
    print(result)
# Out:
# {'_id': 'Marketing', 'average_salary': 4500.0}
# {'_id': 'Finance', 'average_salary': 4500.0}
# {'_id': 'HR', 'average_salary': 7166.666666666667}
# {'_id': 'IT', 'average_salary': 5750.0}

# %%
collection = db['employees']

employee_data_multiple = [
    {'name': 'Navid', 'department': 'HR', 'age': 28, 'salary': 7000},
    {'name': 'Kiki', 'department': 'IT', 'age': 27, 'salary': 6000},
    {'name': 'Hasan', 'department': 'IT', 'age': 30, 'salary': 5500},
    {'name': 'Bogeng', 'department': 'Marketing', 'age': 32, 'salary': 4500},
    {'name': 'Marvel', 'department': 'HR', 'age': 25, 'salary': 7000},
    {'name': 'Restu', 'department': 'IT', 'age': 23, 'salary': 6000},
    {'name': 'Mawan', 'department': 'IT', 'age': 22, 'salary': 3500},
    {'name': 'Samtot', 'department': 'Marketing', 'age': 21, 'salary': 7500},
    {'name': 'Budi', 'department': 'HR', 'age': 28, 'salary': 7500},
    {'name': 'Azqia', 'department': 'IT', 'age': 24, 'salary': 5000},
    {'name': 'Indah', 'department': 'IT', 'age': 19, 'salary': 5500},
    {'name': 'Navid', 'department': 'Marketing', 'age': 30, 'salary': 4500}
]
collection.insert_many(employee_data_multiple)


pipeline = [
    {'$sort': {'department': 1, 'salary': -1}},
    {'$group': {
        '_id': '$department',
        'employees': {'$push': {'name': '$name', 'salary': '$salary', 'age': '$age'}},
    }},
    {'$project': {
        '_id': 1,
        'employees': {'$slice': ['$employees', 5]}
    }}
]

result = collection.aggregate(pipeline)

print('Karyawan dengan Gaji Tertinggi dalam Setiap Departemen:')
for department in result:
    print(f"Departemen: {department['_id']}")
    for employee in department['employees']:
        print(f"Nama: {employee['name']}, Gaji: {employee['salary']}")
# Out:
# Karyawan dengan Gaji Tertinggi dalam Setiap Departemen:
# Departemen: Finance
# Nama: Alice, Gaji: 4500
# Departemen: IT
# Nama: Restu, Gaji: 6000
# Nama: Rio, Gaji: 6000
# Nama: Kiki, Gaji: 6000
# Nama: Hasan, Gaji: 5500
# Nama: Indah, Gaji: 5500
# Departemen: Marketing
# Nama: Samtot, Gaji: 7500
# Nama: Bogeng, Gaji: 4500
# Nama: Navid, Gaji: 4500
# Nama: Bogeng, Gaji: 4500
# Nama: David, Gaji: 4500
# Departemen: HR
# Nama: Budi, Gaji: 7500
# Nama: Tea, Gaji: 7500
# Nama: Aji, Gaji: 7000
# Nama: Marvel, Gaji: 7000
# Nama: Navid, Gaji: 7000

# %%
result = collection.delete_many({'age': {'$lt': 25}})

print(f"{result.deleted_count} karyawan berhasil dihapus karena berusia di bawah 25 tahun.")
# Out:
# 5 karyawan berhasil dihapus karena berusia di bawah 25 tahun.

# %%
pipeline = [
    {'$group': {
        '_id': '$department',
        'total_salary': {'$sum': '$salary'},
        'average_age': {'$avg': '$age'}
    }},
    {'$sort': {'_id': 1}}
]

result = collection.aggregate(pipeline)

print('Laporan Ringkas (Total Gaji dan Rata-rata Umur per Departemen):')
for department in result:
    print(f"Departemen: {department['_id']}")
    print(f"  Total Gaji: {department['total_salary']}")
    print(f"  Rata-rata Umur: {department['average_age']:.2f}")
# Out:
# Laporan Ringkas (Total Gaji dan Rata-rata Umur per Departemen):
# Departemen: Finance
#   Total Gaji: 4500
#   Rata-rata Umur: 29.00
# Departemen: HR
#   Total Gaji: 43000
#   Rata-rata Umur: 27.00
# Departemen: IT
#   Total Gaji: 23000
#   Rata-rata Umur: 28.50
# Departemen: Marketing
#   Total Gaji: 22500
#   Rata-rata Umur: 30.40
